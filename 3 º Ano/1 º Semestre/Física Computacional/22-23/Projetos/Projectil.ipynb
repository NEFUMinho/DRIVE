# %%
import numpy as np
from math import cos, sin, tan, exp, radians, sqrt, log
from numpy import arange
import matplotlib.pyplot as plt

# %% [markdown]
# # Projeto secundário

# %%
#Projeto secundário
vo = 700
phi = 50
h = 1000
g = 9.8
yc = []
xc = arange(0,50066,0.1)
for i in xc:
    yc.append(h+(tan(radians(phi))*i)-((g*i*i)/(2*vox*vox)))
plt.plot(xc,yc,color='green')
plt.grid(True)

# %% [markdown]
# # Movimento obliquo sem atrito

# %%
# Projeto universitário - Movimento obliquo sem atrito, Método de Euler
vo = 700
phi = 50
yo = 1000
g = 9.8
x = [0]
y = [yo]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
h = 25.6
i = 0
while y[i] >= 0:
    x.append(x[i]+(h*vx[i]))
    y.append(y[i]+(h*vy[i]))
    vx.append(vx[i])
    vy.append(vy[i]-(h*g))
    i += 1
plt.plot(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo sem atrito, Runge kutta 2ª Ordem
def dv():
    return 0,-9.8
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
h = 1000
g = 9.8
x = [0]
y = [h]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
h = 25.6
i = 0
while y[i] >= 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv()
    k2x,k2y = dr(vx[i]+((h*k1vx)/2),vy[i]+((h*k1vy)/2))
    k2vx,k2vy = dv()
    x.append(x[i]+(h*(k1x+k2x)/2))
    y.append(y[i]+(h*(k1y+k2y)/2))
    vx.append(vx[i]+(h*(k1vx+k2vx)/2))
    vy.append(vy[i]+(h*(k1vy+k2vy)/2))
    i += 1
plt.plot(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo sem atrito, Runge kutta 4ª Ordem
def dv():
    return 0,-9.8
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
yo = 1000
g = 9.8

x = [0]
y = [yo]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
h = 25.6
i = 0
while y[i] >= 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv()
    k2x,k2y = dr(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2))
    k2vx,k2vy = dv()
    k3x,k3y = dr(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2))
    k3vx,k3vy = dv()
    k4x,k4y = dr(vx[i]+(k3vx*h),vy[i]+(k3vy*h))
    k4vx,k4vy = dv()
    x.append(x[i]+(h*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(h*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(h*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(h*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1
    
plt.plot(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo sem atrito, Runge kutta 6ª Ordem
def dv():
    return 0,-9.8
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
h = 1000
g = 9.8
x = [0]
y = [h]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
dt = 25.6
i = 0
while y[i] >= 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv()
    k2x,k2y = dr(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k2vx,k2vy = dv()
    k3x,k3y = dr(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k3vx,k3vy = dv()
    k4x,k4y = dr(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k4vx,k4vy = dv()
    k5x,k5y = dr(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k5vx,k5vy = dv()
    k6x,k6y = dr(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    k6vx,k6vy = dv()
    x.append(x[i]+(dt*(7*k1x+32*k3x+12*k4x+32*k5x+7*k6x)/90))
    y.append(y[i]+(dt*(7*k1y+32*k3y+12*k4y+32*k5y+7*k6y)/90))
    vx.append(vx[i]+(dt*(7*k1vx+32*k3vx+12*k4vx+32*k5vx+7*k6vx)/90))
    vy.append(vy[i]+(dt*(7*k1vy+32*k3vy+12*k4vy+32*k5vy+7*k6vy)/90))
    i += 1
plt.plot(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %% [markdown]
# # Movimento obliquo com atrito proporcional velocidade

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional velocidade
vo = 700
phi = 50
h = 1000
b = 0.01 * m
g = 9.8
vox = vo*cos(radians(phi))
voy = vo*sin(radians(phi))
yc = [h]
xc = [0]
i = 0
while yc[i] >= 0:
    xc.append(xc[i]+1)
    i += 1
    yc.append(yc[0]+((((m*g)/(b*vox))+(tan(radians(phi))))*xc[i])+((((m**2)*g)/(b**2))*log(1-((b*xc[i])/(m*vox)))))
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional velocidade, Método de Euler
vo = 700
phi = 50
h = 1000
b = 0.01 * m
g = 9.8
x = [0]
y = [h]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
dt = 1
i = 0 
while y[i] >= 0:
    x.append(x[i]+(vx[i]*dt))
    y.append(y[i]+(vy[i]*dt))
    vx.append(vx[i]-(dt*(((b/m)*(vx[i])))))
    vy.append(vy[i]-(dt*(g+((b/m)*(vy[i])))))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á velocidade, Runge kutta 4ª Ordem
def dv(vx,vy):
    return (-((b/m)*(vx))),(-g-((b/m)*(vy)))
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
h = 1000
b = 0.01 * m
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] >= 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i])
    k2x,k2y = dr(vx[i]+((k1vx*dt)/2),vy[i]+((k1vy*dt)/2))
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/2),vy[i]+((k1vy*dt)/2))
    k3x,k3y = dr(vx[i]+((k2vx*dt)/2),vy[i]+((k2vy*dt)/2))
    k3vx,k3vy = dv(vx[i]+((k2vx*dt)/2),vy[i]+((k2vy*dt)/2))
    k4x,k4y = dr(vx[i]+(k3vx*dt),vy[i]+(k3vy*dt))
    k4vx,k4vy = dv(vx[i]+(k3vx*dt),vy[i]+(k3vy*dt))
    x.append(x[i]+(dt*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(dt*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(dt*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(dt*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á velocidade, Runge kutta 6ª Ordem
def dv(vx,vy):
    return (-((b/m)*(vx))),(-g-((b/m)*(vy)))
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
m = 100
h = 1000
b = 0.01 * m
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] >= 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i])
    k2x,k2y = dr(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k3x,k3y = dr(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k3vx,k3vy = dv(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k4x,k4y = dr(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k4vx,k4vy = dv(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k5x,k5y = dr(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k5vx,k5vy = dv(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k6x,k6y = dr(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    k6vx,k6vy = dv(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    x.append(x[i]+(dt*(7*k1x+32*k3x+12*k4x+32*k5x+7*k6x)/90))
    y.append(y[i]+(dt*(7*k1y+32*k3y+12*k4y+32*k5y+7*k6y)/90))
    vx.append(vx[i]+(dt*(7*k1vx+32*k3vx+12*k4vx+32*k5vx+7*k6vx)/90))
    vy.append(vy[i]+(dt*(7*k1vy+32*k3vy+12*k4vy+32*k5vy+7*k6vy)/90))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %% [markdown]
# # Movimento obliquo com atrito proporcional ao quadrado da velocidade

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional ao quadrado da velocidade, Método de Euler
vo = 700
phi = 50
m = 100
yo = 1000
b = 0.00004 * m
g = 9.8

x = [0]
y = [yo]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
h = 1
i = 0 
while y[i] >= 0:
    vx.append(vx[i]-(h*((b/m)*(vx[i]*(sqrt((vx[i]**2)+(vy[i]**2)))))))
    vy.append(vy[i]-(h*(g+((b/m)*(vy[i]*(sqrt((vx[i]**2)+(vy[i]**2))))))))
    x.append(x[i]+((vx[i])*h))
    y.append(y[i]+((vy[i])*h))
    i += 1

plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional ao quadrado da velocidade, Runge kutta 4ª Ordem
vo = 700
phi = 50
m = 100
yo = 1000
b = 0.00004 * m
g = 9.8

def dv(vx,vy):
    return (-((b/m)*(vx*(sqrt((vx**2)+(vy**2)))))),(-g-((b/m)*(vy*(sqrt((vx**2)+(vy**2))))))
def dr(vx,vy):
    return vx,vy
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [yo]
h = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i])
    k2x,k2y = dr(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2))
    k2vx,k2vy = dv(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2))
    k3x,k3y = dr(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2))
    k3vx,k3vy = dv(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2))
    k4x,k4y = dr(vx[i]+(k3vx*h),vy[i]+(k3vy*h))
    k4vx,k4vy = dv(vx[i]+(k3vx*h),vy[i]+(k3vy*h))
    x.append(x[i]+(dt*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(dt*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(dt*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(dt*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1

plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional ao quadrado da velocidade, Runge kutta 6ª Ordem
def dv(vx,vy):
    return (-((b/m)*(vx*(sqrt((vx**2)+(vy**2)))))),(-g-((b/m)*(vy*(sqrt((vx**2)+(vy**2))))))
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
m = 100
h = 1000
b = 0.00004 * m
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i])
    k2x,k2y = dr(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k3x,k3y = dr(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k3vx,k3vy = dv(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k4x,k4y = dr(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k4vx,k4vy = dv(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k5x,k5y = dr(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k5vx,k5vy = dv(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k6x,k6y = dr(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    k6vx,k6vy = dv(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    x.append(x[i]+(dt*(7*k1x+32*k3x+12*k4x+32*k5x+7*k6x)/90))
    y.append(y[i]+(dt*(7*k1y+32*k3y+12*k4y+32*k5y+7*k6y)/90))
    vx.append(vx[i]+(dt*(7*k1vx+32*k3vx+12*k4vx+32*k5vx+7*k6vx)/90))
    vy.append(vy[i]+(dt*(7*k1vy+32*k3vy+12*k4vy+32*k5vy+7*k6vy)/90))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %% [markdown]
# # Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade

# %%
#Função da densidade do ar
def T(y):
    To = 288.15
    L = 0.0065
    return To-(L*y)
def p(y):
    po = 101325
    L = 0.0065
    To = 288.15
    g = 9.8
    M = 0.0289644
    R = 8.31447 
    return po*((1-((L*y)/To))**((g*M)/(R*L)))
def rho_(y):
    M = 0.0289644
    R = 8.31447 
    return ((p(y)*M)/(R*T(y)))

def rho(y):
    po = 101325
    L = 0.0065
    To = 288.15
    g = 9.8
    M = 0.0289644
    R = 8.31447 
    rhoo = po*M/R*To
    Hn = 1/(((g*M)/(R*To))-(L/To))
    return rhoo*exp(-y/Hn)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade, Método de Euler
vo = 700
phi = 50
m = 100
h = 1000
b = 0.00004 * m
g = 9.8
x = [0]
y = [h]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
dt = 1
i = 0 
while y[i] >= 0:
    vx.append(vx[i]-(dt*((b/m)*(rho(y[i])/rho(0))*(vx[i]*(sqrt((vx[i]**2)+(vy[i]**2)))))))
    vy.append(vy[i]-(dt*(g+((b/m)*(rho(y[i])/rho(0))*(vy[i]*(sqrt((vx[i]**2)+(vy[i]**2))))))))
    x.append(x[i]+((vx[i])*dt))
    y.append(y[i]+((vy[i])*dt))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade, Runge kutta 4ª Ordem
vo = 700
phi = 50
m = 100
yo = 1000
b = 0.00004 * m
g = 9.8
yc = []
xc = arange(0,50066,0.1)
for i in xc:
    yc.append(yo+(tan(radians(phi))*i)-((g*i*i)/(2*vo*cos(radians(phi))*vo*cos(radians(phi)))))
plt.plot(xc,yc,color='green')
plt.grid(True)
def dv(vx,vy,y):
    return (-((b/m)*(rho(y)/rho(0))*(vx*(sqrt((vx**2)+(vy**2)))))),(-g-((b/m)*(rho(y)/rho(0))*(vy*(sqrt((vx**2)+(vy**2))))))
def dr(vx,vy):
    return vx,vy
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [yo]
h = 0.01
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i],y[i])
    k2x,k2y = dr(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2))
    k2vx,k2vy = dv(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2),y[i]+((k1y*h)/2))
    k3x,k3y = dr(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2))
    k3vx,k3vy = dv(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2),y[i]+((k2y*h)/2))
    k4x,k4y = dr(vx[i]+(k3vx*h),vy[i]+(k3vy*h))
    k4vx,k4vy = dv(vx[i]+(k3vx*h),vy[i]+(k3vy*h),y[i]+(k3y*h))
    x.append(x[i]+(h*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(h*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(h*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(h*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1
plt.title('Trajetorias')
plt.plot(x,y,color='red')
plt.plot(xc,yc,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade, Runge kutta 6ª Ordem
def dv(vx,vy,y):
    return (-((b/m)*(rho(y)/rho(0))*(vx*(sqrt((vx**2)+(vy**2)))))),(-g-((b/m)*(rho(y)/rho(0))*(vy*(sqrt((vx**2)+(vy**2))))))
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
m = 100
h = 1000
b = 0.00004 * m
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i],y[i])
    k2x,k2y = dr(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4))
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4),y[i]+((k1y*dt)/4))
    k3x,k3y = dr(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8))
    k3vx,k3vy = dv(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8),y[i]+(((k2y+k1y)*dt)/8))
    k4x,k4y = dr(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt))
    k4vx,k4vy = dv(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt),y[i]+((k3y-(k2y/2))*dt))
    k5x,k5y = dr(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16))
    k5vx,k5vy = dv(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16),y[i]+((3*k1y+9*k4y)*dt/16))
    k6x,k6y = dr(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7))
    k6vx,k6vy = dv(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7),y[i]+((-3*k1y+2*k2y+12*k3y-12*k4y+8*k5y)*dt/7))
    x.append(x[i]+(dt*(7*k1x+32*k3x+12*k4x+32*k5x+7*k6x)/90))
    y.append(y[i]+(dt*(7*k1y+32*k3y+12*k4y+32*k5y+7*k6y)/90))
    vx.append(vx[i]+(dt*(7*k1vx+32*k3vx+12*k4vx+32*k5vx+7*k6vx)/90))
    vy.append(vy[i]+(dt*(7*k1vy+32*k3vy+12*k4vy+32*k5vy+7*k6vy)/90))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %% [markdown]
# # Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade + Vento

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade + Vento, Método de Euler
vo = 700
phi = 50
m = 100
h = 1000
b = 0.00004 * m
vv = 100
g = 9.8
x = [0]
y = [h]
vx = [vo*cos(radians(phi))]
vy = [vo*sin(radians(phi))]
dt = 1
i = 0
while y[i] > 0:
    x.append(x[i]+((vx[i]-vv)*dt))
    y.append(y[i]+(vy[i]*dt))
    vx.append(vx[i]-(dt*(((b/m)*(rho(y[i])/rho(0))*((vx[i]-vv)*(sqrt(((vx[i]-vv)**2)+(vy[i]**2))))))))
    vy.append(vy[i]-(dt*(g+((b/m)*(rho(y[i])/rho(0))*(vy[i]*(sqrt(((vx[i]-vv)**2)+(vy[i]**2))))))))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade + Vento, Runge kutta 4ª Ordem
vo = 700
phi = 50
m = 100
yo = 1000
b = 0.00004 * m
vv = 100
g = 9.8

def dv(vx,vy,y,vv):
    return -((b/m)*(rho(y)/rho(0))*(vx-vv)*sqrt(((vx-vv)**2)+(vy**2))),-g-((b/m)*(rho(y)/rho(0))*vy*sqrt(((vx-vv)**2)+(vy**2)))
def dr(vx,vy,vv):
    return vx-vv,vy
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [yo]
h = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i],vv)
    k1vx,k1vy = dv(vx[i],vy[i],y[i],vv)
    k2x,k2y = dr(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2),vv)
    k2vx,k2vy = dv(vx[i]+((k1vx*h)/2),vy[i]+((k1vy*h)/2),y[i]+((k1y*h)/2),vv)
    k3x,k3y = dr(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2),vv)
    k3vx,k3vy = dv(vx[i]+((k2vx*h)/2),vy[i]+((k2vy*h)/2),y[i]+((k2y*h)/2),vv)
    k4x,k4y = dr(vx[i]+(k3vx*h),vy[i]+(k3vy*h),vv)
    k4vx,k4vy = dv(vx[i]+(k3vx*h),vy[i]+(k3vy*h),y[i]+(k3y*h),vv)
    x.append(x[i]+(dt*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(dt*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(dt*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(dt*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1
    
plt.plot(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
#Projeto universitário - Movimento obliquo com atrito proporcional á densidade do ar e quadrado da velocidade + Vento, Runge kutta 6ª Ordem
def dv(vx,vy,y,vv):
    return (-((b/m)*(rho(y)/rho(0))*((vx-vv)*(sqrt(((vx-vv)**2)+(vy**2)))))),(-g-((b/m)*(rho(y)/rho(0))*(vy*(sqrt(((vx-vv)**2)+(vy**2))))))
def dr(vx,vy,vv):
    return vx-vv,vy
vo = 700
phi = 50
m = 100
h = 1000
b = 0.00004 * m
vv = 100
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i],vv)
    k1vx,k1vy = dv(vx[i],vy[i],y[i],vv)
    k2x,k2y = dr(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4),vv)
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/4),vy[i]+((k1vy*dt)/4),y[i]+((k1y*dt)/4),vv)
    k3x,k3y = dr(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8),vv)
    k3vx,k3vy = dv(vx[i]+(((k2vx+k1vx)*dt)/8),vy[i]+(((k2vy+k1vy)*dt)/8),y[i]+(((k2y+k1y)*dt)/8),vv)
    k4x,k4y = dr(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt),vv)
    k4vx,k4vy = dv(vx[i]+((k3vx-(k2vx/2))*dt),vy[i]+((k3vy-(k2vy/2))*dt),y[i]+((k3y-(k2y/2))*dt),vv)
    k5x,k5y = dr(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16),vv)
    k5vx,k5vy = dv(vx[i]+((3*k1vx+9*k4vx)*dt/16),vy[i]+((3*k1vy+9*k4vy)*dt/16),y[i]+((3*k1y+9*k4y)*dt/16),vv)
    k6x,k6y = dr(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7),vv)
    k6vx,k6vy = dv(vx[i]+((-3*k1vx+2*k2vx+12*k3vx-12*k4vx+8*k5vx)*dt/7),vy[i]+((-3*k1vy+2*k2vy+12*k3vy-12*k4vy+8*k5vy)*dt/7),y[i]+((-3*k1y+2*k2y+12*k3y-12*k4y+8*k5y)*dt/7),vv)
    x.append(x[i]+(dt*(7*k1x+32*k3x+12*k4x+32*k5x+7*k6x)/90))
    y.append(y[i]+(dt*(7*k1y+32*k3y+12*k4y+32*k5y+7*k6y)/90))
    vx.append(vx[i]+(dt*(7*k1vx+32*k3vx+12*k4vx+32*k5vx+7*k6vx)/90))
    vy.append(vy[i]+(dt*(7*k1vy+32*k3vy+12*k4vy+32*k5vy+7*k6vy)/90))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)

# %%
def dv(vx,vy,y):
    return -u*((cd*vx*(rho(y)/rho(0)))+(cl*vy))*sqrt(((vx)**2)+(vy**2)),-g-u*((cd*vy*(rho(y)/rho(0)))-(cl*vx))*sqrt(((vx)**2)+(vy**2))
def dr(vx,vy):
    return vx,vy
vo = 700
phi = 50
h = 1000
u = 0.00004
cd = 0.2
cl = -0.6
g = 9.8
vy = [vo*sin(radians(phi))]
vx = [vo*cos(radians(phi))]
x = [0]
y = [h]
dt = 1
i = 0
while y[i] > 0:
    k1x,k1y = dr(vx[i],vy[i])
    k1vx,k1vy = dv(vx[i],vy[i],y[i])
    k2x,k2y = dr(vx[i]+((k1vx*dt)/2),vy[i]+((k1vy*dt)/2))
    k2vx,k2vy = dv(vx[i]+((k1vx*dt)/2),vy[i]+((k1vy*dt)/2),y[i]+((k1y*dt)/2))
    k3x,k3y = dr(vx[i]+((k2vx*dt)/2),vy[i]+((k2vy*dt)/2))
    k3vx,k3vy = dv(vx[i]+((k2vx*dt)/2),vy[i]+((k2vy*dt)/2),y[i]+((k2y*dt)/2))
    k4x,k4y = dr(vx[i]+(k3vx*dt),vy[i]+(k3vy*dt))
    k4vx,k4vy = dv(vx[i]+(k3vx*dt),vy[i]+(k3vy*dt),y[i]+(k3y*dt))
    x.append(x[i]+(dt*(k1x+2*k2x+2*k3x+k4x)/6))
    y.append(y[i]+(dt*(k1y+2*k2y+2*k3y+k4y)/6))
    vx.append(vx[i]+(dt*(k1vx+2*k2vx+2*k3vx+k4vx)/6))
    vy.append(vy[i]+(dt*(k1vy+2*k2vy+2*k3vy+k4vy)/6))
    i += 1
plt.scatter(x,y,color='red')
plt.plot(x,y,color='green')
plt.grid(True)
