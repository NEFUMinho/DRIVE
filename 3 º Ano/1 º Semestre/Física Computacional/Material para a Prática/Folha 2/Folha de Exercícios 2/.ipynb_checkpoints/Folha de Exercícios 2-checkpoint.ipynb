# %%
#exercício 1
from math import sqrt,sin,pi
from pylab import imshow,gray,show,colorbar
from numpy import empty

#dados da função de onda(igual para as duas):
A=1
k=2*pi/5


#gráfico
separation = 20.0
side = 100.0
points = 500
spacing = side/points




x1=side/2 + separation/2
y1=side/2
x2=side/2 - separation/2
y2=side/2

xi=empty([points,points], float)

for i in range(points):
    y=spacing*i
    for j in range(points):
        x= spacing*j
        r1=sqrt((x-x1)**2 + (y-y1)**2)
        r2=sqrt((x-x2)**2 + (y-y2)**2)
        xi[i,j] = (A*sin(k*r1)) + (A * sin(k*r2))
        
#Make plot
plot = imshow(xi, origin= "lower", extent=[0,side,0,side])
cb=colorbar(plot)
gray()
show()

#Terminado

# %%
#exercício 2

# %%
#exercício 3

# %%
#exercício 4

# %%
#exercício 5

# %%
#exercício 6

# %%
#exercício 7

# %%
#exercício 8
